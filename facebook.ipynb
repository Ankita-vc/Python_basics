# %%
https://www.facebook.com/Infostretch.Corporation/?ref=br_rs

# %%
import facebook

# %%
token="EAACh7rYfWOoBAJV5CEHpSXFgUp1N92Nz8IJ4FcNb797ob52edUQro2mAy8LrZADlSItnZChkbWnH87vXZAU2AA9JJjtGvKQFS71MTORLkUQUUKlKD4SvLhKBpc6N1sYjHsUhrxghzhy3Dl85H9sXk4EMKgnb2EZD"

graph = facebook.GraphAPI(access_token=token, version = 3.0)

#pratiksha
#https://scontent-sin2-1.xx.fbcdn.net/v/t1.0-9/45073566_1137658973077442_6816032009769451520_n.jpg?_nc_cat=104&_nc_ht=scontent-sin2-1.xx&oh=dc0fc910fca9a60e9ed23a31041d8855&oe=5C89706C
#https://scontent-sin2-1.xx.fbcdn.net/v/t1.0-9/45193678_1137658999744106_2431020449530904576_n.jpg?_nc_cat=107&_nc_ht=scontent-sin2-1.xx&oh=38f1f653e97203612f838ad8c7494f3d&oe=5C89D2DD
#add limit(0) to removes list of likes and get only summary 
# u'order': u'chronological mean sorted order old to new
events = graph.request("/1817955871593028/feed?fields=shares,likes.limit(0).summary(true),comments.limit(0).summary(true),message")


#for accessing page
#link of page - https://www.facebook.com/Project-563459204103665/
#events = graph.request("/563459204103665")


#ebby
#events = graph.request("/v3.0/10217805920645250/feed")


#for all my fb page fields
#events = graph.request("me?fields=id,name,likes{created_time,bio},feed.include_hidden(true){actions,from,message},albums{from},photos{from,id,likes,comments{from,message}}")


#ankita
#events = graph.request("/1817955871593028/feed")


#my page id
#page id - 563459204103665

# %%
type(events)
#u.encode('ascii', 'ignore')
# Out:
# dict

# %%
events
# Out:
# {u'albums': {u'data': [{u'from': {u'id': u'1136936659816340',
#      u'name': u'Pratiksha Sheth'},
#     u'id': u'874362146073794'},
#    {u'from': {u'id': u'1136936659816340', u'name': u'Pratiksha Sheth'},
#     u'id': u'111245959052087'},
#    {u'from': {u'id': u'1136936659816340', u'name': u'Pratiksha Sheth'},
#     u'id': u'438387963004550'},
#    {u'from': {u'id': u'1136936659816340', u'name': u'Pratiksha Sheth'},
#     u'id': u'104275889749094'}],
#   u'paging': {u'cursors': {u'after': u'MTA0Mjc1ODg5NzQ5MDk0',
#     u'before': u'ODc0MzYyMTQ2MDczNzk0'}}},
#  u'feed': {u'data': [{u'actions': [{u'link': u'https://www.facebook.com/1136936659816340/posts/1137659223077417',
#       u'name': u'Comment'},
#      {u'link': u'https://www.facebook.com/1136936659816340/posts/1137659223077417',
#       u'name': u'Like'},
#      {u'link': u'https://www.facebook.com/1136936659816340/posts/1137659223077417',
#       u'name': u'Share'}],
# ...

# %%
eventList = events['data']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-129ae9431d77> in <module>()
# ----> 1 eventList = events['data']
#
# KeyError: 'data'

# %%
eventList
# Out:
# [{u'comments': {u'data': [],
#    u'summary': {u'can_comment': True,
#     u'order': u'chronological',
#     u'total_count': 2}},
#   u'id': u'1136936659816340_1137659223077417',
#   u'likes': {u'data': [],
#    u'summary': {u'can_like': True, u'has_liked': False, u'total_count': 103}},
#   u'message': u'Diwali celebration @Infostretch #Trad Day #Infoneers\u2764\u2764\u2764 @ Infostretch Solutions Pvt Ltd'},
#  {u'comments': {u'data': [],
#    u'summary': {u'can_comment': True,
#     u'order': u'chronological',
#     u'total_count': 1}},
#   u'id': u'1136936659816340_1134731686703504',
#   u'likes': {u'data': [],
#    u'summary': {u'can_like': True, u'has_liked': False, u'total_count': 6}},
#   u'message': u'Miss u priya.. \u2764\u2764\u2764\u2764'},
#  {u'comments': {u'data': [],
#    u'summary': {u'can_comment': True,
#     u'order': u'chronological',
#     u'total_count': 6}},
#   u'id': u'1136936659816340_1113145195528820',
#   u'likes': {u'data': [],
# ...

# %%
type(eventList)
# Out:
# list

# %%
for line in eventList:
    print(line['comments']['summary']['total_count'])
# Out:
# 2
# 1
# 6
# 18
# 0
# 0
# 1
# 18
# 9
# 1
# 1
# 34
# 18
# 10
# 2
# 12
# 5
# 9
# 5
# 11
# 30
# 13
# 2
# 20
# 17
